# %%
# !pip install pgmpy





import pandas as pd
from pgmpy.estimators import MaximumLikelihoodEstimator
from pgmpy.models import BayesianModel
from pgmpy.inference import VariableElimination

data = pd.read_csv("heart disease.csv")
heart_disease = pd.DataFrame(data)
print(heart_disease)

model = BayesianModel([
    ('age', 'Lifestyle'),('Gender', 'Lifestyle'),
    ('Family', 'heartdisease'),
    ('diet', 'cholestrol'),
    ('Lifestyle', 'diet'),
    ('cholestrol', 'heartdisease'),
    ('diet', 'cholestrol')
])

model.fit(heart_disease, estimator=MaximumLikelihoodEstimator)

HeartDisease_infer = VariableElimination(model)

print('For Age enter SuperSeniorCitizen:0, SeniorCitizen:1, MiddleAged:2, Youth:3, Teen:4')
print('For Gender enter Male:0, Female:1')
print('For Family History enter Yes:1, No:0')
print('For Diet enter High:0, Medium:1')
print('for LifeStyle enter Athlete:0, Active:1, Moderate:2, Sedentary:3')
print('for Cholesterol enter High:0, BorderLine:1, Normal:2')



q = HeartDisease_infer.query(variables=['heartdisease'], evidence={
    'age': int(input('Enter Age: ')),
    'Gender': int(input('Enter Gender: ')),
    'Family': int(input('Enter Family History: ')),
    'diet': int(input('Enter Diet: ')),
    'Lifestyle': int(input('Enter Lifestyle: ')),
    'cholestrol': int(input('Enter Cholestrol: '))
})

print(q)
# Out:
# WARNING:pgmpy:BayesianModel has been renamed to BayesianNetwork. Please use BayesianNetwork class, BayesianModel will be removed in future.
# Requirement already satisfied: pgmpy in c:\users\91932\anaconda3\lib\site-packages (0.1.26)
# Requirement already satisfied: networkx in c:\users\91932\anaconda3\lib\site-packages (from pgmpy) (3.3)
# Requirement already satisfied: numpy in c:\users\91932\anaconda3\lib\site-packages (from pgmpy) (1.26.4)
# Requirement already satisfied: scipy in c:\users\91932\anaconda3\lib\site-packages (from pgmpy) (1.13.1)
# Requirement already satisfied: scikit-learn in c:\users\91932\anaconda3\lib\site-packages (from pgmpy) (1.5.1)
# Requirement already satisfied: pandas in c:\users\91932\anaconda3\lib\site-packages (from pgmpy) (2.2.2)
# Requirement already satisfied: pyparsing in c:\users\91932\anaconda3\lib\site-packages (from pgmpy) (3.1.2)
# Requirement already satisfied: torch in c:\users\91932\anaconda3\lib\site-packages (from pgmpy) (2.5.1)
# Requirement already satisfied: statsmodels in c:\users\91932\anaconda3\lib\site-packages (from pgmpy) (0.14.2)
# Requirement already satisfied: tqdm in c:\users\91932\anaconda3\lib\site-packages (from pgmpy) (4.66.5)
# Requirement already satisfied: joblib in c:\users\91932\anaconda3\lib\site-packages (from pgmpy) (1.4.2)
# Requirement already satisfied: opt-einsum in c:\users\91932\anaconda3\lib\site-packages (from pgmpy) (3.4.0)
# Requirement already satisfied: xgboost in c:\users\91932\anaconda3\lib\site-packages (from pgmpy) (2.1.2)
# Requirement already satisfied: google-generativeai in c:\users\91932\anaconda3\lib\site-packages (from pgmpy) (0.8.3)
# Requirement already satisfied: google-ai-generativelanguage==0.6.10 in c:\users\91932\anaconda3\lib\site-packages (from google-generativeai->pgmpy) (0.6.10)
# Requirement already satisfied: google-api-core in c:\users\91932\anaconda3\lib\site-packages (from google-generativeai->pgmpy) (2.23.0)
# Requirement already satisfied: google-api-python-client in c:\users\91932\anaconda3\lib\site-packages (from google-generativeai->pgmpy) (2.151.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\91932\anaconda3\lib\site-packages (from google-generativeai->pgmpy) (2.36.0)
# Requirement already satisfied: protobuf in c:\users\91932\anaconda3\lib\site-packages (from google-generativeai->pgmpy) (5.28.3)
# Requirement already satisfied: pydantic in c:\users\91932\anaconda3\lib\site-packages (from google-generativeai->pgmpy) (2.8.2)
# Requirement already satisfied: typing-extensions in c:\users\91932\anaconda3\lib\site-packages (from google-generativeai->pgmpy) (4.11.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\91932\anaconda3\lib\site-packages (from google-ai-generativelanguage==0.6.10->google-generativeai->pgmpy) (1.25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\91932\anaconda3\lib\site-packages (from pandas->pgmpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\91932\anaconda3\lib\site-packages (from pandas->pgmpy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\91932\anaconda3\lib\site-packages (from pandas->pgmpy) (2023.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\91932\anaconda3\lib\site-packages (from scikit-learn->pgmpy) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\91932\anaconda3\lib\site-packages (from statsmodels->pgmpy) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\91932\anaconda3\lib\site-packages (from statsmodels->pgmpy) (24.1)
# Requirement already satisfied: filelock in c:\users\91932\anaconda3\lib\site-packages (from torch->pgmpy) (3.13.1)
# Requirement already satisfied: jinja2 in c:\users\91932\anaconda3\lib\site-packages (from torch->pgmpy) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\91932\anaconda3\lib\site-packages (from torch->pgmpy) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\91932\anaconda3\lib\site-packages (from torch->pgmpy) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\91932\anaconda3\lib\site-packages (from torch->pgmpy) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\91932\anaconda3\lib\site-packages (from sympy==1.13.1->torch->pgmpy) (1.3.0)
# Requirement already satisfied: colorama in c:\users\91932\anaconda3\lib\site-packages (from tqdm->pgmpy) (0.4.6)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\91932\anaconda3\lib\site-packages (from google-api-core->google-generativeai->pgmpy) (1.65.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\91932\anaconda3\lib\site-packages (from google-api-core->google-generativeai->pgmpy) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\91932\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai->pgmpy) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\91932\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai->pgmpy) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\91932\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai->pgmpy) (4.9)
# Requirement already satisfied: six in c:\users\91932\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels->pgmpy) (1.16.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\users\91932\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai->pgmpy) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\91932\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai->pgmpy) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\91932\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai->pgmpy) (4.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\91932\anaconda3\lib\site-packages (from jinja2->torch->pgmpy) (2.1.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\91932\anaconda3\lib\site-packages (from pydantic->google-generativeai->pgmpy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\91932\anaconda3\lib\site-packages (from pydantic->google-generativeai->pgmpy) (2.20.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\91932\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai->pgmpy) (1.67.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\91932\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai->pgmpy) (1.67.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\91932\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai->pgmpy) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\91932\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai->pgmpy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\91932\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai->pgmpy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\91932\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai->pgmpy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\91932\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai->pgmpy) (2024.8.30)
#     age  Gender  Family  diet  Lifestyle  cholestrol  heartdisease
# 0     0       0       1     1          3           0             1
# 1     0       1       1     1          3           0             1
# 2     1       0       0     0          2           1             1
# 3     4       0       1     1          3           2             0
# 4     3       1       1     0          0           2             0
# 5     2       0       1     1          1           0             1
# 6     4       0       1     0          2           0             1
# 7     0       0       1     1          3           0             1
# 8     3       1       1     0          0           2             0
# 9     1       1       0     0          0           2             1
# 10    4       1       0     1          2           0             1
# 11    4       0       1     1          3           2             0
# 12    2       1       0     0          0           0             0
# 13    2       0       1     1          1           0             1
# 14    3       1       1     0          0           1             0
# 15    0       0       1     0          0           2             1
# 16    1       1       0     1          2           1             1
# 17    3       1       1     1          0           1             0
# 18    4       0       1     1          3           2             0
# For Age enter SuperSeniorCitizen:0, SeniorCitizen:1, MiddleAged:2, Youth:3, Teen:4
# For Gender enter Male:0, Female:1
# For Family History enter Yes:1, No:0
# For Diet enter High:0, Medium:1
# for LifeStyle enter Athlete:0, Active:1, Moderate:2, Sedentary:3
# for Cholesterol enter High:0, BorderLine:1, Normal:2
# Enter Age:  1
# Enter Gender:  1
# Enter Family History:  1
# Enter Diet:  1
# Enter Lifestyle:  1
# Enter Cholestrol:  1
# WARNING:pgmpy:BayesianModel has been renamed to BayesianNetwork. Please use BayesianNetwork class, BayesianModel will be removed in future.
# WARNING:pgmpy:BayesianModel has been renamed to BayesianNetwork. Please use BayesianNetwork class, BayesianModel will be removed in future.
# +-----------------+---------------------+
# | heartdisease    |   phi(heartdisease) |
# +=================+=====================+
# | heartdisease(0) |              1.0000 |
# +-----------------+---------------------+
# | heartdisease(1) |              0.0000 |
# +-----------------+---------------------+
